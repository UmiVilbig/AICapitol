# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("trades.csv")
data.drop(["MonitorPrice"], axis=1, inplace=True)

# %%
data.head()
# Out:
#          id           member Ticker Type      Bought   BuyPrice  Amount  \
# 0  20001934     Lou Barletta    DDD    S  10/22/2014  36.669998   15000
# 1  20000404  John A. Boehner    CAH    s  02/27/2014  53.021889   15000
# 2  20000404  John A. Boehner    slB    P  02/26/2014  69.109833   50000
# 3  20000404  John A. Boehner    WMT    s  02/25/2014  19.527540   50000
# 4  20001087  John A. Boehner     KN    S  05/20/2014  29.540001   15000
#
#    FilePrice      Spot7     Spot30     Spot90    Spot180
# 0  36.669998  37.099998  35.150002  29.320000  32.500000
# 1  53.021889  53.560749  51.661263  51.490734  54.630642
# 2  69.109833  68.855377  73.016212  76.451126  82.801132
# 3  19.527540  20.001425  20.401081        NaN  20.551355
# 4  29.540001  28.160000  31.930000  31.959999  19.850000

# %%
len(data)
# Out:
# 5032

# %%
data.dropna(inplace=True)

# %%
len(data)
# Out:
# 4255

# %%
# more data wrangling
data['Ticker'] = data['Ticker'].str.upper()
data['Type'] = data['Type'].str.upper()

float_columns = ['BuyPrice', 'FilePrice', 'Spot7', 'Spot30', 'Spot90', 'Spot180']
data[float_columns] = data[float_columns].round(2)

data["Profitable7"] = (data["FilePrice"] < data["Spot7"]).astype(int)
data["Profitable30"] = (data["FilePrice"] < data["Spot30"]).astype(int)
data["Profitable90"] = (data["FilePrice"] < data["Spot90"]).astype(int)
data["Profitable180"] = (data["FilePrice"] < data["Spot180"]).astype(int)

# %%
data.head()
# Out:
#          id           member Ticker Type      Bought  BuyPrice  Amount  \
# 0  20001934     Lou Barletta    DDD    S  10/22/2014     36.67   15000
# 1  20000404  John A. Boehner    CAH    S  02/27/2014     53.02   15000
# 2  20000404  John A. Boehner    SLB    P  02/26/2014     69.11   50000
# 4  20001087  John A. Boehner     KN    S  05/20/2014     29.54   15000
# 5  20001087  John A. Boehner   QCOM    P  05/22/2014     58.52   50000
#
#    FilePrice  Spot7  Spot30  Spot90  Spot180  Profitable7  Profitable30  \
# 0      36.67  37.10   35.15   29.32    32.50            1             0
# 1      53.02  53.56   51.66   51.49    54.63            1             0
# 2      69.11  68.86   73.02   76.45    82.80            0             1
# 4      29.54  28.16   31.93   31.96    19.85            0             1
# 5      58.52  58.99   59.05   56.52    53.54            1             1
#
#    Profitable90  Profitable180
# 0             0              0
# 1             0              1
# 2             1              1
# 4             1              0
# 5             0              0

# %%
categorical_features = ["member", "Ticker", "Type"]
numerical_features = ['BuyPrice', 'Amount']
categorical_transformer = OneHotEncoder(handle_unknown="ignore")
numerical_transformer = SimpleImputer(strategy='mean')

preprocessor = ColumnTransformer(
    transformers=[
        ("cat", categorical_transformer, categorical_features),
        ('num', numerical_transformer, numerical_features)
    ]
)

# %%
X = data[categorical_features + numerical_features]
y = data['Profitable90']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=69)

# %%
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(random_state=100))
])

# %%
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.46      0.55       254
#            1       0.71      0.85      0.77       385
#
#     accuracy                           0.70       639
#    macro avg       0.69      0.66      0.66       639
# weighted avg       0.69      0.70      0.68       639

# %%
# hyperparam tuning
param_grid = {
    'classifier__n_estimators': [100, 250, 500, 750],  
    'classifier__max_depth': [None], #, 10, 20, 30, 40],  
    'classifier__min_samples_split': [2], # 5, 10, 15],  
    'classifier__min_samples_leaf': [1], #, 2, 4, 6],  
    'classifier__max_features': ['sqrt', 'log2', None],  
    'classifier__bootstrap': [True, False], 
    'classifier__class_weight': [None, 'balanced']  
}

grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    refit='f1',
    verbose=2,
)

grid_search.fit(X_train, y_train)

print("Best parameters found:")
print(grid_search.best_params_)

print("Best score found:")
print(grid_search.best_score_)

best_model = grid_search.best_estimator_

test_score = best_model.score(X_test, y_test)
print(f"Test score: {test_score}")
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.4s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.4s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   6.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   6.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   6.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   6.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   6.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.2s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.2s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.2s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   7.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   6.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   7.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   6.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   7.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   4.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   3.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   3.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   3.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   3.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  10.2s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  10.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   8.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   9.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  10.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  20.4s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  20.2s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  18.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  19.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  19.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  30.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  29.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  26.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  29.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  29.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   0.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   4.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   7.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   7.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   7.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   7.2s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   7.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   2.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   5.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   5.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   5.4s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   5.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   6.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   8.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   7.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   8.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   8.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=   8.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   3.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   3.2s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   3.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   3.2s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   3.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   8.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   8.3s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   7.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   8.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   7.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  17.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  15.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  15.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  16.2s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  15.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  24.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  23.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  21.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  23.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  23.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.0s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   6.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   6.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.0s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   6.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  10.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  10.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  10.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  10.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  10.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.6s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.6s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.2s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  10.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  11.0s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  10.9s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  11.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  11.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   6.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   6.0s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   6.2s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   6.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   6.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  16.2s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  15.2s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  16.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  16.6s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  15.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  32.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  30.9s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  33.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  33.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  32.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  49.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  46.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  48.2s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  49.9s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  46.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.9s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   3.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.9s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   7.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  11.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  11.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  11.6s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  11.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  11.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.6s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.6s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   1.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   4.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   4.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   4.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   4.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=   4.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   8.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   8.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   8.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   8.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=   8.9s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  13.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  12.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  12.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  12.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  13.2s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   4.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   5.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   5.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   5.9s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; total time=   4.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  12.0s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  14.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  13.9s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  14.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=250; total time=  12.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  24.2s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  29.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  27.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  29.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=500; total time=  24.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  36.0s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  44.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  41.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  44.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=None, classifier__max_features=None, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=750; total time=  36.4s
# Best parameters found:
# {'classifier__bootstrap': True, 'classifier__class_weight': None, 'classifier__max_depth': None, 'classifier__max_features': None, 'classifier__min_samples_leaf': 1, 'classifier__min_samples_split': 2, 'classifier__n_estimators': 250}
# Best score found:
# 0.6714594652422763
# Test score: 0.6995305164319249

# %%
import pickle
# save model
model = best_model

with open("model.pkl", "wb") as f:
    pickle.dump(model, f)
